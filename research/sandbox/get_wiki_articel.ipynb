# %%
import wikipedia

def wiki_suche(suchbegriff, sprache='de'):
    wikipedia.set_lang(sprache)

    try:
        # Direkten Artikel versuchen
        seite = wikipedia.page(suchbegriff)
        print(f"✅ Exakter Artikel gefunden: {seite.title}")
    except (wikipedia.DisambiguationError, wikipedia.PageError):
        # Kein direkter Artikel, versuche sinnvollen Alternativartikel
        vorschlaege = wikipedia.search(suchbegriff)
        for kandidat in vorschlaege:
            try:
                seite = wikipedia.page(kandidat)
                print(f"🔎 Automatisch weitergeleiteter Artikel: {seite.title}")
                print(f"🔗 URL: {seite.url}")
                return
            except:
                continue
        print("❌ Kein passender Artikel gefunden.")

# Beispiel
wiki_suche("FIFA-Korruptionsaffäre")

# %%
import wikipedia
import requests

def wiki_suche(suchbegriff, sprache='de'):
    wikipedia.set_lang(sprache)

    try:
        # Direkten Artikel versuchen
        seite = wikipedia.page(suchbegriff)
        print(f"✅ Exakter Artikel gefunden: {seite.title}")
    except (wikipedia.DisambiguationError, wikipedia.PageError):
        # Kein direkter Artikel, versuche sinnvollen Alternativartikel
        vorschlaege = wikipedia.search(suchbegriff)
        for kandidat in vorschlaege:
            try:
                seite = wikipedia.page(kandidat)
                print(f"🔎 Automatisch weitergeleiteter Artikel: {seite.title}")
                print(f"🔗 URL: {seite.url}")
                break
            except:
                continue
        else:
            print("❌ Kein passender Artikel gefunden.")
            return

    print(f"🔗 URL: {seite.url}")
    print(f"\n🕘 Lade die komplette Bearbeitungshistorie für „{seite.title}“:\n")

    # Versionsgeschichte abrufen
    alle_revisionen(seite.title, sprache)

def alle_revisionen(titel, sprache='de'):
    revisions = []
    url = f"https://{sprache}.wikipedia.org/w/api.php"

    params = {
        "action": "query",
        "format": "json",
        "prop": "revisions",
        "titles": titel,
        "rvlimit": "500",  # max. erlaubt (für die erste Anfrage)
        "rvprop": "timestamp|user|comment",
        "redirects": 1
    }

    while True:
        response = requests.get(url, params=params)
        data = response.json()
        page = next(iter(data["query"]["pages"].values()))
        revs = page.get("revisions", [])
        revisions.extend(revs)

        # Fortschritt anzeigen
        print(f"↪️  {len(revisions)} Revisionen gesammelt...", end="\r")

        # Check auf weiteres "continue"-Token (Paginierung)
        if "continue" in data:
            params["rvcontinue"] = data["continue"]["rvcontinue"]
        else:
            break

    print(f"\n✅ Insgesamt {len(revisions)} Revisionen gefunden.\n")

    # Ausgabe der gesammelten Revisionen
    for rev in revisions:
        zeit = rev['timestamp'].replace("T", " ").replace("Z", "")
        benutzer = rev.get('user', 'Unbekannt')
        kommentar = rev.get('comment', '')
        print(f"- {zeit} | {benutzer} | {kommentar}")

    return revisions

# Beispiel
wiki_suche("FIFA-Korruptionsaffäre")
# Out:
# /opt/anaconda3/envs/WAVE/lib/python3.12/site-packages/wikipedia/wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /opt/anaconda3/envs/WAVE/lib/python3.12/site-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# 🔎 Automatisch weitergeleiteter Artikel: Garcia-Bericht
# 🔗 URL: https://de.wikipedia.org/wiki/Garcia-Bericht
# 🔗 URL: https://de.wikipedia.org/wiki/Garcia-Bericht
#
# 🕘 Lade die komplette Bearbeitungshistorie für „Garcia-Bericht“:
#
# ↪️  63 Revisionen gesammelt...
# ✅ Insgesamt 63 Revisionen gefunden.
#
# - 2023-11-28 10:08:58 | Kristbaum | Bild hinzugefügt #suggestededit-add-image-top
# - 2023-05-08 18:16:43 | InternetArchiveBot | [[:Benutzer:InternetArchiveBot|InternetArchiveBot]] hat 0 Archivlink(s) ergänzt und 1 Link(s) als defekt/tot markiert.) #IABot (v2.0.9.3
# - 2022-11-20 23:28:19 | Derkoenig | Botmarkierung gepüft
# - 2022-06-18 00:54:58 | APPERbot | Bot: externe Links von Kursivauszeichnung getrennt
# - 2022-01-31 14:43:42 | CamelBot | Bot: linkfix: mobile/amp; siehe [[user:CamelBot]].
# - 2021-03-13 09:06:57 | Aka | /* Hintergrund */ [[Benutzer:Aka/Tippfehler entfernt|Tippfehler entfernt]]
# - 2021-03-13 07:18:35 | 194.230.147.114 | /* Folgen */Tippfehler korrigiert
# - 2020-05-03 19:12:42 | Toni Müller | /* Folgen */ +
# - 2019-01-04 21:59:08 | Sprachpfleger | /* Folgen */ plus s
# - 2018-12-29 11:12:00 | Aka | /* Folgen */ Leerzeichen vor Referenz entfernt
# - 2018-04-19 10:09:07 | Dmicha | /* Hintergrund */ Abrufdatum korrigiert
# - 2018-04-11 13:52:31 | InternetArchiveBot | [[:Benutzer:InternetArchiveBot|InternetArchiveBot]] hat 0 Archivlink(s) ergänzt und 1 Link(s) als defekt/tot markiert. #IABot (v1.6.5)
# - 2017-06-30 09:19:05 | Anne Winsch | /* Folgen */ welt.de
# - 2017-06-30 08:51:03 | Anne Winsch | /* Folgen */ handelsblatt
# - 2017-06-30 08:35:38 | Anne Winsch | /* Folgen */ nzz
# - 2017-06-30 08:03:34 | Anne Winsch | /* Hintergrund */
# - 2017-06-28 18:35:14 | SamWinchester000 | /* Hintergrund */
# - 2017-06-28 17:17:58 | Anne Winsch | /* Hintergrund */
# - 2017-06-28 17:02:47 | Mattes | [[WP:HC|HC]]: Ergänze [[Kategorie:Fußballgeschichte]]
# - 2017-06-28 16:03:30 | Anne Winsch | /* Hintergrund */
# - 2017-06-28 16:01:36 | Anne Winsch | /* Hintergrund */
# - 2017-06-28 15:00:35 | Bildungsbürger | /* Hintergrund */
# - 2017-06-28 14:28:54 | Anne Winsch | Damals war er nicht ehemalig
# - 2017-06-28 14:07:59 | Anne Winsch | /* Hintergrund */ Rücktritt
# - 2017-06-28 13:52:52 | Anne Winsch | /* Hintergrund */ ergänzt
# - 2017-06-28 13:38:42 | Anne Winsch | /* Hintergrund */ ergänzt
# - 2017-06-28 11:53:30 | 85.181.7.111 | angepasst
# - 2017-06-28 10:08:22 | Kopiersperre | Kopiersperre verschob die Seite [[Garcia-Report]] nach [[Garcia-Bericht]]
